# %% [markdown]
# <a href="https://colab.research.google.com/github/sangyx/deep-business/blob/main/notebook/deep_business.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Set up environment

# %%
# !git clone https://github.com/sangyx/deep-business.git
# Out:
# Cloning into 'deep-business'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 51 (delta 21), reused 39 (delta 13), pack-reused 0
# Receiving objects: 100% (51/51), 3.02 MiB | 7.40 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
# !pip install -r deep-business/requirements.txt
# Out:
# Collecting openai==0.27.8 (from -r deep-business/requirements.txt (line 1))
#   Downloading openai-0.27.8-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 1.7 MB/s eta 0:00:00
# Collecting pymupdf==1.22.5 (from -r deep-business/requirements.txt (line 2))
#   Downloading PyMuPDF-1.22.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 26.0 MB/s eta 0:00:00
# Requirement already satisfied: tenacity==8.2.2 in /usr/local/lib/python3.10/dist-packages (from -r deep-business/requirements.txt (line 3)) (8.2.2)
# Collecting tiktoken==0.4.0 (from -r deep-business/requirements.txt (line 4))
#   Downloading tiktoken-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 35.3 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.27.8->-r deep-business/requirements.txt (line 1)) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.27.8->-r deep-business/requirements.txt (line 1)) (4.65.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.27.8->-r deep-business/requirements.txt (line 1)) (3.8.5)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken==0.4.0->-r deep-business/requirements.txt (line 4)) (2022.10.31)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.27.8->-r deep-business/requirements.txt (line 1)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.27.8->-r deep-business/requirements.txt (line 1)) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.27.8->-r deep-business/requirements.txt (line 1)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.27.8->-r deep-business/requirements.txt (line 1)) (3.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.8->-r deep-business/requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.8->-r deep-business/requirements.txt (line 1)) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.8->-r deep-business/requirements.txt (line 1)) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.8->-r deep-business/requirements.txt (line 1)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.8->-r deep-business/requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.27.8->-r deep-business/requirements.txt (line 1)) (1.3.1)
# Installing collected packages: pymupdf, tiktoken, openai
# Successfully installed openai-0.27.8 pymupdf-1.22.5 tiktoken-0.4.0

# %%
from IPython.display import HTML, display

def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)

# %% [markdown]
# ### Chat with your paper
#
# Please upload the paper you want to chat with to the folder `pdf`:
#
# ![upload.png](data:image/png;base64,...)

# %% [markdown]
# **Note that you must use the official version of the paper downloaded from the journal's website to make the built-in parse templates take effect.** The support journals and their jcode (abbreviation):
#
# * `mnsc`: Management Science
# * `isre`: Information Systems Research
# * `misq`: MIS Quarterly
# * `ijoc`: INFORMS Journal on Computing
# * `mksc`: Marketing Science
# * `opre`: Operations Research
# * `msom`: Manufacturing & Service Operations Management
# * `orsc`: Organization Science

# %%
jcode = "mnsc"
pdf_path = "/content/pdf/mnsc.2022.4449.pdf"

openai_key = "sk-xxxx"
model = "16k"

# %%
# !python deep-business/chat_business/chat_paper.py --jcode {jcode} --pdf_path {pdf_path} --openai_key {openai_key} --model {model}
# Out:
# The chapters of paper [Machine Learning vs. Economic Restrictions: Evidence from Stock Return Predictability]:
# 1. Introduction
# 2. Methodology and Data
#   2.1. Methodology and Data Sources
#   2.2. Subsamples with Economic Restrictions
# 3. Return Predictability in the Presence of Economic Restrictions
#   3.1. Evidence from NN3-Predicted Returns
#   3.2. Evidence from the Adversarial Approach
#   3.3. Evidence from IPCA and the CA
#   3.4. Nonnormality, Turnover, and Trading Costs of Machine Learning Portfolios
#   3.5. Performance and Weights of the SDF-Implied Tangency Portfolio
# 4. Time-Varying Return Predictability
#   4.1. Analysis Based on Portfolio Returns
#   4.2. Time Series Regressions
#   4.3. Return Predictability in Recent Years
# 5. Economic Foundations of Machine Learning
#   5.1. Stock Characteristics of Machine Learning Portfolios
#   5.2. Intra-Industry vs. Inter-Industry Return Predictability
# 6. Conclusion
#
# ----------------------------------------------------------------------------------------------------
# Summarize paper with [Introduction] and [Conclution]...
#
# 1. Summarize the paper's content in one sentence.
# Machine learning methods in finance, particularly deep learning techniques, are analyzed in terms of their economic significance, profitability, and viability, revealing challenges and potential benefits.
#
# 2. What problem does the paper attempt to solve? Is this a new problem?
# The paper aims to evaluate the economic significance of machine learning methods in finance, considering their use in generating investment signals and their performance relative to traditional approaches. While the problem of evaluating investment strategies is not new, the focus on machine learning methods and their economic foundations is relatively recent.
#
# 3. What scientific hypothesis is the paper attempting to test?
# The paper aims to test the working hypothesis that machine learning signals, generated by aggregating multiple anomalies, can provide economically significant and profitable investment strategies, even when accounting for trading restrictions and frictions.
#
# 4. What were the solutions used in the past, and what were the problems associated with them? Is the proposed solution well motivated?
# In the past, traditional finance approaches relied on cross-sectional regressions and portfolio sorts based on individual anomalies to predict stock returns. However, recent studies have challenged the credibility of these approaches by highlighting issues with false discoveries, limited profitability, and the concentration of anomalies in distressed stocks. The proposed solution of employing machine learning methods is well motivated by their ability to accommodate high-dimensional predictor sets, identify complex patterns, and mitigate overfitting biases.
#
# 5. What is the key to the proposed solution?
# The key to the proposed solution is the utilization of machine learning methods, specifically deep learning techniques, to aggregate multiple anomalies and generate investment signals. These methods can handle a large number of predictors, capture nonlinear relationships, and select models through regularization techniques.
#
# 6. How were the experiments in the paper designed? What are the data sets used? What are the metrics used to evaluate the results?
# The experiments in the paper employ a large sample of U.S. stocks from 1987 to 2017. The authors analyze various machine learning methods, including neural networks and conditional beta pricing models. They evaluate the investment profitability based on value-weighted portfolios and consider metrics such as average monthly return, Fama-French six-factor-adjusted return, portfolio turnover, and transaction costs.
#
# 7. What are the findings in the paper? Is there good support for the scientific hypothesis that needs to be tested?
# The findings suggest that while machine learning signals initially demonstrate outstanding performance relative to traditional approaches, their economic significance weakens when accounting for trading restrictions. The profitability of deep learning methods, in particular, diminishes significantly when excluding microcaps, firms without credit rating coverage, or financially distressed firms. The paper provides strong support for the hypothesis that economic restrictions and trading frictions pose challenges to the viability and profitability of machine learning-based investment strategies.
#
# 8. What are the next steps? Is there any work that can be continued?
# The paper suggests several future research directions, such as exploring optimization routines that can account for high turnover and trading costs, endogenously considering portfolio constraints, evaluating practical transaction costs of strategic trading, and further examining the economic foundations and implications of machine learning methods in finance.
#
# Total Token Used: 4591 | Response Time: 18.388s
# ----------------------------------------------------------------------------------------------------
